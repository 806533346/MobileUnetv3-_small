# %% [markdown]
# # 安装配置环境

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# accelerate                1.13.0
# annotated-doc             0.0.4
# anyio                     4.10.0
# argon2-cffi               21.3.0
# argon2-cffi-bindings      25.1.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.16.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# brotlicffi                1.1.0.0
# certifi                   2025.11.12
# cffi                      2.0.0
# charset-normalizer        3.4.4
# click                     8.3.3
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.1
# cycler                    0.11.0
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.20.0
# filelock                  3.19.1
# ...

# %% [markdown]
# ## 安装 Pytorch

# %%
# !pip3 install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...

# %% [markdown]
# ## 安装 ONNX

# %%
# !pip install onnx -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/17.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/17.2 MB ? eta -:--:--
#      - -------------------------------------- 0.8/17.2 MB 2.1 MB/s eta 0:00:08
#      ---- ----------------------------------- 2.1/17.2 MB 3.6 MB/s eta 0:00:05
#      ---------- ----------------------------- 4.7/17.2 MB 6.1 MB/s eta 0:00:03
#      --------------- ------------------------ 6.8/17.2 MB 7.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 10.2/17.2 MB 9.2 MB/s eta 0:00:01
#      -------------------------- ------------- 11.5/17.2 MB 9.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 12.1/17.2 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------------- 17.2/17.2 MB 9.9 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
# ...

# %% [markdown]
# ## 安装推理引擎 ONNX Runtime

# %%
# !pip install onnxruntime -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/13.4 MB ? eta -:--:--
#       --------------------------------------- 0.3/13.4 MB ? eta -:--:--
#      --- ------------------------------------ 1.3/13.4 MB 3.2 MB/s eta 0:00:04
#      ------ --------------------------------- 2.1/13.4 MB 3.7 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/13.4 MB 5.7 MB/s eta 0:00:02
#      ------------------------ --------------- 8.1/13.4 MB 8.0 MB/s eta 0:00:01
#      --------------------------------- ------ 11.3/13.4 MB 9.4 MB/s eta 0:00:01
#      -------------------------------------- - 12.8/13.4 MB 9.0 MB/s eta 0:00:01
#      ---------------------------------------- 13.4/13.4 MB 8.2 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [flatbuffers]
#    -------------------- ------------------- 1/2 [onnxruntime]
#    -------------------- ------------------- 1/2 [onnxruntime]
# ...

# %% [markdown]
# ## 安装其它第三方工具包

# %%
# !pip install numpy pandas matplotlib tqdm opencv-python pillow -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.0/9.8 MB 4.6 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.6/9.8 MB 6.3 MB/s eta 0:00:02
#      --------------------------------- ------ 8.1/9.8 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------------- 9.8/9.8 MB 13.8 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#      --- ------------------------------------ 3.9/44.0 MB 59.2 MB/s eta 0:00:01
#      ------ --------------------------------- 7.3/44.0 MB 25.2 MB/s eta 0:00:02
#      --------- ----------------------------- 10.7/44.0 MB 20.4 MB/s eta 0:00:02
#      ------------ -------------------------- 14.2/44.0 MB 18.9 MB/s eta 0:00:02
#      --------------- ----------------------- 17.3/44.0 MB 17.9 MB/s eta 0:00:02
# ...

# %%
pip install fvcore -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 验证安装配置成功

# %%
import fvcore

print('fvcore 版本', fvcore.__version__)
# Out:
# fvcore 版本 0.1.5.post20221221

# %%
import torch
print('PyTorch 版本', torch.__version__)
# Out:
# PyTorch 版本 2.8.0+cu126

# %%
import onnx
print('ONNX 版本', onnx.__version__)
# Out:
# ONNX 版本 1.22.0

# %%
import onnxruntime as ort
print('ONNX Runtime 版本', ort.__version__)
# Out:
# ONNX Runtime 版本 1.27.0

# %%
## 安装其它第三方工具包
# !pip install numpy pandas matplotlib tqdm opencv-python pillow -i https://pypi.tuna.tsinghua.edu.cn/simple

## 安装深度学习相关工具包
# !pip install torchsummary fvcore albumentations scikit-learn pyyaml -i https://pypi.tuna.tsinghua.edu.cn/simple

## 安装数据处理和可视化工具包
# !pip install Pillow scipy seaborn -i https://pypi.tuna.tsinghua.edu.cn/simple

## 验证所有包安装成功
import torch
import torchvision
import onnx
import onnxruntime as ort
import torchsummary
import albumentations as albu
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yaml
from sklearn.model_selection import train_test_split
from tqdm import tqdm

print('PyTorch 版本:', torch.__version__)
print('ONNX 版本:', onnx.__version__)
print('ONNX Runtime 版本:', ort.__version__)
print('torchsummary 版本:', torchsummary.__version__)
print('albumentations 版本:', albu.__version__)
print('OpenCV 版本:', cv2.__version__)
print('所有包安装成功！')
